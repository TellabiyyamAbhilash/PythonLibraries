# %%
import seaborn as sns
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
plt.figure(figsize=(12,6))
bins = [10, 20, 30, 40, 50, 60, 70, 80]
sns.scatterplot(x = 'age', y= 'fare', hue = "class", data= df, sizes = [20,15,8,9,4], markers = ["p"])
plt.xticks(bins)
# Out:
# ([<matplotlib.axis.XTick at 0x1dd4831d400>,
#   <matplotlib.axis.XTick at 0x1dd4831c290>,
#   <matplotlib.axis.XTick at 0x1dd483314f0>,
#   <matplotlib.axis.XTick at 0x1dd48368ef0>,
#   <matplotlib.axis.XTick at 0x1dd48242b10>,
#   <matplotlib.axis.XTick at 0x1dd483685f0>,
#   <matplotlib.axis.XTick at 0x1dd48369e20>,
#   <matplotlib.axis.XTick at 0x1dd4836a510>],
#  [Text(10, 0, '10'),
#   Text(20, 0, '20'),
#   Text(30, 0, '30'),
#   Text(40, 0, '40'),
#   Text(50, 0, '50'),
#   Text(60, 0, '60'),
#   Text(70, 0, '70'),
#   Text(80, 0, '80')])
